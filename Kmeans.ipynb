# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import KMeans

# %%
test = np.array([1,2,3,50,55,60,100,110,120])

# %%
km = KMeans(n_clusters=3)

# %%
km.fit_predict(test.reshape(-1,1))
# Out:
# C:\Users\L\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# array([1, 1, 1, 2, 2, 2, 0, 0, 0])

# %%
df = pd.read_csv('Mall_Customers.csv')

# %%
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.drop('CustomerID',axis=1,inplace=True)

# %%
df
# Out:
#       Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0      Male   19                  15                      39
# 1      Male   21                  15                      81
# 2    Female   20                  16                       6
# 3    Female   23                  16                      77
# 4    Female   31                  17                      40
# ..      ...  ...                 ...                     ...
# 195  Female   35                 120                      79
# 196  Female   45                 126                      28
# 197    Male   32                 126                      74
# 198    Male   32                 137                      18
# 199    Male   30                 137                      83
#
# [200 rows x 4 columns]

# %%
df = pd.get_dummies(df, drop_first=True, dtype='int')

# %%
df
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)  Genre_Male
# 0     19                  15                      39           1
# 1     21                  15                      81           1
# 2     20                  16                       6           0
# 3     23                  16                      77           0
# 4     31                  17                      40           0
# ..   ...                 ...                     ...         ...
# 195   35                 120                      79           0
# 196   45                 126                      28           0
# 197   32                 126                      74           1
# 198   32                 137                      18           1
# 199   30                 137                      83           1
#
# [200 rows x 4 columns]

# %%
sns.pairplot(df)
# Out:
# C:\Users\L\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\L\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\L\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
km = KMeans(n_clusters=5)

# %%
preds = km.fit_predict(df)
# Out:
# C:\Users\L\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
preds
# Out:
# array([0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4,
#        0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4,
#        0, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 3, 1, 2, 1, 3, 1, 3, 1,
#        3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 2, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1,
#        3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1,
#        3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1,
#        3, 1])

# %%
df.columns
# Out:
# Index(['Age', 'Annual Income (k$)', 'Spending Score (1-100)', 'Genre_Male'], dtype='object')

# %%
col1 = df.iloc[:,1]

# %%
col2 = df.iloc[:,2]

# %%
df.iloc[preds==0,1]
# Out:
# 0     15
# 2     16
# 4     17
# 6     18
# 8     19
# 10    19
# 12    20
# 14    20
# 16    21
# 18    23
# 20    24
# 22    25
# 24    28
# 26    28
# 28    29
# 30    30
# 32    33
# 34    33
# 36    34
# 38    37
# 40    38
# 42    39
# 44    39
# Name: Annual Income (k$), dtype: int64

# %%
plt.scatter(df.iloc[preds==0,1], df.iloc[preds==0,2], color='red')
plt.scatter(df.iloc[preds==1,1], df.iloc[preds==1,2], color='blue')
plt.scatter(df.iloc[preds==2,1], df.iloc[preds==2,2], color='black')
plt.scatter(df.iloc[preds==3,1], df.iloc[preds==3,2], color='green')
plt.scatter(df.iloc[preds==4,1], df.iloc[preds==4,2], color='yellow')
